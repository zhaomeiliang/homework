# %%
# 单变量描述统计

##无序类别变量描述统计

import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"]#设置字体
df = pd.read_spss(R'data/identity.sav')

# %%
df['民族'].value_counts(normalize=True)
# Out:
# 民族
# 汉族      0.424277
# 回族      0.152601
# 藏族      0.057803
# 蒙古族     0.057803
# 壮族      0.054335
# 土家族     0.053179
# 维吾尔族    0.053179
# 苗族      0.039306
# 彝族      0.017341
# 白族      0.017341
# 满族      0.012717
# 哈萨克族    0.011561
# 瑶族      0.009249
# 布依族     0.008092
# 侗族      0.005780
# 东乡族     0.004624
# 黎族      0.003468
# 哈尼族     0.003468
# 水族      0.002312
# 仫佬族     0.002312
# 羌族      0.002312
# 畲族      0.001156
# 土族      0.001156
# 其他      0.001156
# 保安族     0.001156
# 裕固族     0.001156
# 毛难族     0.001156
# Name: proportion, dtype: float64

# %%
x = df['民族'].value_counts().index
y = df['民族'].value_counts(normalize=True).values * 100
fig,ax2 = plt.subplots()
labels = df['民族'].value_counts().index
ax2.pie(y,autopct='%1.1f%%',labels=labels,textprops=dict(color="w"))
plt.show()

# %%
# 有序定类变量描述统计，可增加累计次数和累计比例的统计。可采用饼图或柱状图
df['年级'].value_counts()
# Out:
# 年级
# 大一    307
# 大二    278
# 大三    172
# 大四     94
# 预科     14
# Name: count, dtype: int64

# %%
from pyreadstat import pyreadstat

国家认同调查数据表,metadata = pyreadstat.read_sav(R'data\identity.sav',apply_value_formats=True,formats_as_ordered_category=True)
result = 国家认同调查数据表['会打多少分'].value_counts(sort=False)

# %%
国家认同调查数据表['年级'].value_counts(sort=False)
# Out:
# 年级
# 预科     14
# 大一    307
# 大二    278
# 大三    172
# 大四     94
# Name: count, dtype: int64

# %%
df_result = pd.DataFrame(国家认同调查数据表['年级'].value_counts(sort=False))  
df_result['累计求和'] = df_result['count'].cumsum()  
# df_result['新变量1'] = 1  
# df_result['新变量2'] = df_result['新变量1'] + 1  
df_result['比例'] = df_result.groupby('年级').size().div(df_result.groupby('年级').size().sum(), axis=0)  # normalize=True效果一样  
df_result['累计比例'] = df_result['比例'].cumsum()

# %%
df_result
# Out:
#     count  累计求和   比例  累计比例
# 年级
# 预科     14    14  0.2   0.2
# 大一    307   321  0.2   0.4
# 大二    278   599  0.2   0.6
# 大三    172   771  0.2   0.8
# 大四     94   865  0.2   1.0

# %%
import matplotlib.pyplot as plt  
  
# 假设 x 和 y 是从 DataFrame 中提取的列  
x = list(df_result.index)  
y = list(df_result['count'])  
  
fig, ax2 = plt.subplots()  
ax2.pie(y, labels=x, autopct='%1.1f%%') # 如果需要显示百分比  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
x = df_result.index  
y = df_result['count'].values  
  
fig, ax = plt.subplots()  # ax 是轴对象  
ax.bar(x, y)  
plt.show()

# %%
import mytools
描述统计结果表 = mytools.有序变量描述统计函数(国家认同调查数据表,'年级')
描述统计结果表
# Out:
#     count        比例      累计比例
# 年级
# 预科     14  0.016185  0.016185
# 大一    307  0.354913  0.371098
# 大二    278  0.321387  0.692486
# 大三    172  0.198844  0.891329
# 大四     94  0.108671  1.000000

# %%
mytools.绘制直方图(描述统计结果表)

# %%
描述统计结果表 = mytools.有序变量描述统计函数(国家认同调查数据表,'您觉得中国怎么样')
描述统计结果表
# Out:
#           count        比例      累计比例
# 您觉得中国怎么样
# 很差劲          15  0.017341  0.017341
# 较差           38  0.043931  0.061272
# 一般般         197  0.227746  0.289017
# 挺好          474  0.547977  0.836994
# 十分棒         141  0.163006  1.000000

# %%
mytools.绘制直方图(描述统计结果表)
