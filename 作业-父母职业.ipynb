# %%
import pandas as pd  
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mytools
import seaborn as sns

# %%
data = pd.read_csv(R'data\类别变量练习数据.csv',encoding='GBK')

# %%
print(data.describe())
# Out:
#         父亲工作  母亲工作
# count     53    52
# unique    48    42
# top     市公安局  家庭主妇
# freq       2    10

# %%
#父亲职业的饼图
def create_pie_chart(x, y):
     x=data['父亲职业重新编码'].value_counts().index
y=data['父亲职业重新编码'].value_counts(normalize=True)
fig, ax1 = plt.subplots()
labels = data['父亲职业重新编码' ].value_counts().index
ax1.pie(y,autopct='%1.1f%%', labels=labels, textprops=dict (color="black"))
plt. show()

# %%
#母亲职业的饼图
def create_pie_chart(x, y):
 x=data['母亲职业重新编码'].value_counts().index
y=data['母亲职业重新编码'].value_counts(normalize=True)
fig, ax1 = plt.subplots()
labels = data['母亲职业重新编码' ].value_counts().index
ax1.pie(y,autopct='%1.1f%%', labels=labels, textprops=dict (color="black"))
plt. show()

# %%
tau_y = mytools.goodmanKruska_tau_y(data,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# 0.2031196469236814

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '弱相关'

# %%
mytools.制作交叉表(data,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企        个体  事业单位       公务员   国企      家庭主妇     民企       All
# 父亲职业重新编码
# 个体         0.0  0.500000   0.0  0.000000  0.0  0.181818  0.125  0.117647
# 事业单位       0.0  0.000000   0.2  0.000000  0.0  0.000000  0.000  0.039216
# 公务员        0.0  0.166667   0.7  0.714286  0.0  0.000000  0.500  0.431373
# 国企         0.0  0.166667   0.1  0.000000  1.0  0.090909  0.125  0.098039
# 家庭主妇       0.0  0.000000   0.0  0.071429  0.0  0.181818  0.000  0.058824
# 民企         1.0  0.166667   0.0  0.214286  0.0  0.545455  0.250  0.254902
